# %%
import matplotlib.pylab as plt
from API import transfer_style

# %%
# Path of the pre-trained TF model 
model_path = r"../Neural-Style-Transfer/model"

# NOTE : Works only for '.jpg' and '.png' extensions,other formats may give error
content_image_path = r"Imgs/content6.jpg"
style_image_path = r"Imgs/art7.jpg"
img = transfer_style(content_image_path,style_image_path,model_path)

# Saving the generated image
plt.imsave('stylized_image.jpg',img)
plt.imshow(img)
plt.show()
# Out:
# Loading images...
# Resizing and Normalizing images...
# Loading pre-trained model...
# Generating stylized image now...wait a minute
# Stylizing completed...

# %%
import tensorflow as tf
